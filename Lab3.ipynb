# %% [markdown]
# 1

# %%
import torch

def grad_f(x,y,z):
    
    y = y.clone()
    z = z.clone()
    
    y.requires_grad_(True)
    z.requires_grad_(True)
    
    f = 2*x + (3 - torch.sin(y.matmul(z))**x)
    f.backward()
    
    return (y.grad + z.grad)

# %%
grad_f(3,torch.tensor([1.,1.,1.]), torch.tensor([2.,2.,2.]))
# Out:
# tensor([-0.6747, -0.6747, -0.6747])

# %% [markdown]
# 5

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['intel-image-classification', 'adult-income-dataset']

# %%
# !ls ../input
# Out:
# adult-income-dataset  intel-image-classification

# %%
import torch
from torch import nn
from torchvision import datasets, models, transforms

# %%
import torch.utils.data as tdata

# %%
# !ls ../input/intel-image-classification/seg_train/seg_train/
# !ls ../input/intel-image-classification/seg_test/seg_test/
# Out:
# buildings  forest  glacier  mountain  sea  street
# buildings  forest  glacier  mountain  sea  street

# %%
data_path_format = '../input/intel-image-classification/seg_{0}/seg_{0}'

# %%
np.random.seed(5315)
torch.manual_seed(9784)

# %%
# channel_means = (0.4301, 0.4572, 0.4540)
# channel_stds = (0.2698, 0.2680, 0.2983)  # 0.485, 0.456, 0.406
channel_means = (0.485, 0.456, 0.406)
channel_stds = (0.229, 0.224, 0.225)

# %%
image_transforms = transforms.Compose([
    transforms.Resize((150,150)),
    transforms.ToTensor(),
    transforms.Normalize(channel_means, channel_stds)
])

# %%
image_datasets = dict(zip(('dev', 'test'), [datasets.ImageFolder(data_path_format.format(key),transform=image_transforms) for key in ['train', 'test']]))
print(image_datasets)
# Out:
# {'dev': Dataset ImageFolder
#     Number of datapoints: 14034
#     Root Location: ../input/intel-image-classification/seg_train/seg_train
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None, 'test': Dataset ImageFolder
#     Number of datapoints: 3000
#     Root Location: ../input/intel-image-classification/seg_test/seg_test
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None}

# %%
devset_indices = np.arange(len(image_datasets['dev']))
devset_labels = image_datasets['dev'].targets

# %%
from sklearn import model_selection

# %%
train_indices, val_indices, train_labels,  val_labels = model_selection.train_test_split(devset_indices, devset_labels, test_size=0.1, stratify=devset_labels)

# %%
print(len(val_indices))
# Out:
# 1404

# %%
image_datasets['train'] = tdata.Subset(image_datasets['dev'], train_indices)
image_datasets['validation'] = tdata.Subset(image_datasets['dev'], val_indices)

# %%
print(image_datasets)
# Out:
# {'dev': Dataset ImageFolder
#     Number of datapoints: 14034
#     Root Location: ../input/intel-image-classification/seg_train/seg_train
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None, 'test': Dataset ImageFolder
#     Number of datapoints: 3000
#     Root Location: ../input/intel-image-classification/seg_test/seg_test
#     Transforms (if any): Compose(
#                              Resize(size=(150, 150), interpolation=PIL.Image.BILINEAR)
#                              ToTensor()
#                              Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#                          )
#     Target Transforms (if any): None, 'train': <torch.utils.data.dataset.Subset object at 0x7f53bc52e198>, 'validation': <torch.utils.data.dataset.Subset object at 0x7f53bc52e160>}

# %%
from IPython.display import display

# %%
image_dataloaders = {key: tdata.DataLoader(image_datasets[key], batch_size=16,shuffle=True) for key in  ['train', 'validation']}

# %%
image_dataloaders['test'] = tdata.DataLoader(image_datasets['test'], batch_size=32)

# %%
def imshow(inp, title=None, fig_size=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0)) # C x H x W  # H x W x C
    inp = channel_stds * inp + channel_means
    inp = np.clip(inp, 0, 1)
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot('111')
    ax.imshow(inp)
    if title is not None:
        ax.set_title(title)
    ax.set_aspect('equal')
    plt.pause(0.001)

# %%
imshow(image_datasets['train'][8555][0]) # 5946

# %%
cuda_device = torch.device('cuda')
cpu_device = torch.device('cpu')
device = cuda_device

# %%
import torch.nn as F
class IntelNet(nn.Module):
    def __init__(self):
        super(IntelNet, self).__init__()
        self.Conv2d_1 = nn.Conv2d(3, 4, 3, padding=5)
        self.MaxPool2d_1 = nn.MaxPool2d(2, 2)
        self.ReLU_1 = F.ReLU()
        
        self.Conv2d_2 = nn.Conv2d(4, 8, 3, padding=4)
        self.MaxPool2d_2 = nn.MaxPool2d(2, 2)
        self.ReLU_2 = F.ReLU()
        
        self.Conv2d_3 = nn.Conv2d(8, 16, 3, padding=3)
        self.MaxPool2d_3 = nn.MaxPool2d(2, 2)
        self.ReLU_3 = F.ReLU()
        
        self.Conv2d_4 = nn.Conv2d(16, 32, 3, padding=2)
        self.MaxPool2d_4 = nn.MaxPool2d(2, 2)
        self.ReLU_4 = F.ReLU()
        
        self.Conv2d_5 = nn.Conv2d(32, 64, 3, padding=1)
        self.MaxPool2d_5 = nn.MaxPool2d(2, 2)
        self.ReLU_5 = F.ReLU()
        
        self.Conv2d_6 = nn.Conv2d(64, 128, 3)
        self.MaxPool2d_6 = nn.MaxPool2d(2, 2)
        self.ReLU_6 = F.ReLU()
        
        self.fc = nn.Linear(128*4, 6)
        
    def forward(self, x):
        x = self.MaxPool2d_1(self.Conv2d_1(x))
        x = self.ReLU_1(x)
        
        x = self.MaxPool2d_2(self.Conv2d_2(x))
        x = self.ReLU_2(x)
        
        x = self.MaxPool2d_3(self.Conv2d_3(x))
        x = self.ReLU_3(x)
        
        x = self.MaxPool2d_4(self.Conv2d_4(x))
        x = self.ReLU_4(x)
        
        x = self.MaxPool2d_5(self.Conv2d_5(x))
        x = self.ReLU_5(x)
        
        x = self.MaxPool2d_6(self.Conv2d_6(x))
        x = self.ReLU_6(x)
        x = x.view(x.size(0), x.size(1)*x.size(2)*x.size(3))
        x = self.fc(x)
        
        return x

# %%
class BestModel:
    def __init__(self, path, initial_criterion):
        self.path = path
        self.criterion = initial_criterion
        
    def update(self, model, optimizer, criterion):
        self.criterion = criterion
        torch.save({'model_state': model.state_dict(), 'optimizer_state': optimizer.state_dict(), 'criterion': criterion}, self.path)
        
    def load_model_data(self):
        return torch.load(self.path)
    
    def restore(self, model, optimizer):
        model_data = self.load_model_data()
        model.load_state_dict(model_data['model_state'])
        optimizer.load_state_dict(model_data['optimizer_state'])

# %%
def train_model(epochs, model, optimizer, criterion, loaders, device, best_model, n_prints=1):
    print_every = len(loaders['train']) // n_prints
    for epoch in range(epochs):
        model.train()
        running_train_loss = 0.0
        
        for iteration, (xx, yy) in enumerate(loaders['train']):
            optimizer.zero_grad()
            xx, yy = xx.to(device), yy.to(device)
            out = model(xx)
            loss = criterion(out, yy)
            running_train_loss += loss.item()
            loss.backward()
            optimizer.step()
            
            if(iteration % print_every == print_every - 1):
                running_train_loss /= print_every
                print(f"Epoch {epoch}, iteration {iteration} training_loss {running_train_loss}")
                running_train_loss = 0.0
            
        with torch.no_grad():
            model.eval()
            running_corrects = 0
            running_total = 0
            running_loss = 0.0
            for xx, yy in loaders['validation']:
                batch_size = xx.size(0)
                xx, yy = xx.to(device), yy.to(device)

                out = model(xx)
                
                loss = criterion(out, yy)
                running_loss += loss.item()
                
                predictions = out.argmax(1)
                running_corrects += (predictions == yy).sum().item()
                running_total += batch_size
            
            mean_val_loss = running_loss / len(loaders['validation'])
            accuracy = running_corrects / running_total
            
            if accuracy > best_model.criterion:
                best_model.update(model, optimizer, accuracy)
            
            print(f"Epoch {epoch}, val_loss {mean_val_loss}, accuracy = {accuracy}")
    best_model.restore(model, optimizer)

# %%
import time
start = time.time()

# %%
ptr = IntelNet()
ptr = ptr.to(device)
optimizer = torch.optim.Adam(ptr.parameters(), lr=0.0003)
criterion = nn.CrossEntropyLoss()
best_model = BestModel('resnet_data',0.0)
train_model(10, ptr, optimizer, criterion,image_dataloaders, device, best_model=best_model, n_prints=5)
# Out:
# Epoch 0, iteration 157 training_loss 1.4753283292432375
# Epoch 0, iteration 315 training_loss 1.1285549545589881
# Epoch 0, iteration 473 training_loss 1.0096155340912976
# Epoch 0, iteration 631 training_loss 0.9928722215604179
# Epoch 0, iteration 789 training_loss 0.8879996428761301
# Epoch 0, val_loss 0.8974099999124353, accuracy = 0.6260683760683761
# Epoch 1, iteration 157 training_loss 0.8652558168278465
# Epoch 1, iteration 315 training_loss 0.843975933858111
# Epoch 1, iteration 473 training_loss 0.8211489927165115
# Epoch 1, iteration 631 training_loss 0.745673169440861
# Epoch 1, iteration 789 training_loss 0.806249279010145
# Epoch 1, val_loss 0.7411484840241346, accuracy = 0.7037037037037037
# Epoch 2, iteration 157 training_loss 0.7602688283482685
# Epoch 2, iteration 315 training_loss 0.749342371579967
# Epoch 2, iteration 473 training_loss 0.7113716262805311
# Epoch 2, iteration 631 training_loss 0.6898993801655648
# Epoch 2, iteration 789 training_loss 0.6528545320977138
# Epoch 2, val_loss 0.6454669646918774, accuracy = 0.75
# Epoch 3, iteration 157 training_loss 0.656433417072779
# Epoch 3, iteration 315 training_loss 0.6494591486982152
# Epoch 3, iteration 473 training_loss 0.6603307341095768
# Epoch 3, iteration 631 training_loss 0.6628914303794692
# Epoch 3, iteration 789 training_loss 0.6669871950451332
# Epoch 3, val_loss 0.65268073129383, accuracy = 0.7528490028490028
# Epoch 4, iteration 157 training_loss 0.6291031365907644
# Epoch 4, iteration 315 training_loss 0.6029855277908
# Epoch 4, iteration 473 training_loss 0.6343626154563095
# Epoch 4, iteration 631 training_loss 0.603818463468099
# Epoch 4, iteration 789 training_loss 0.6145785536758507
# Epoch 4, val_loss 0.5901608311317184, accuracy = 0.7777777777777778
# Epoch 5, iteration 157 training_loss 0.5859351098726068
# Epoch 5, iteration 315 training_loss 0.5830735531222971
# Epoch 5, iteration 473 training_loss 0.5714180549677415
# Epoch 5, iteration 631 training_loss 0.5758092082753966
# Epoch 5, iteration 789 training_loss 0.554240456487559
# Epoch 5, val_loss 0.5218783825297247, accuracy = 0.7977207977207977
# Epoch 6, iteration 157 training_loss 0.5226922401144535
# Epoch 6, iteration 315 training_loss 0.5609098123975947
# Epoch 6, iteration 473 training_loss 0.5364680474128904
# Epoch 6, iteration 631 training_loss 0.5393339166346984
# Epoch 6, iteration 789 training_loss 0.5619891127453575
# Epoch 6, val_loss 0.5378462966870178, accuracy = 0.7898860398860399
# Epoch 7, iteration 157 training_loss 0.5352210945720914
# Epoch 7, iteration 315 training_loss 0.5049429164279865
# Epoch 7, iteration 473 training_loss 0.4964988029833081
# Epoch 7, iteration 631 training_loss 0.5129046730602844
# Epoch 7, iteration 789 training_loss 0.5149676630014106
# Epoch 7, val_loss 0.5545233735306696, accuracy = 0.7841880341880342
# Epoch 8, iteration 157 training_loss 0.4741333065719544
# Epoch 8, iteration 315 training_loss 0.4987155525367471
# Epoch 8, iteration 473 training_loss 0.49829769785268396
# Epoch 8, iteration 631 training_loss 0.5005539753769017
# Epoch 8, iteration 789 training_loss 0.4822781271760977
# Epoch 8, val_loss 0.503410443155603, accuracy = 0.8105413105413105
# Epoch 9, iteration 157 training_loss 0.4538525338225727
# Epoch 9, iteration 315 training_loss 0.4782588702119604
# Epoch 9, iteration 473 training_loss 0.4349823584662208
# Epoch 9, iteration 631 training_loss 0.4526689617977112
# Epoch 9, iteration 789 training_loss 0.478492840417201
# Epoch 9, val_loss 0.5349480374292894, accuracy = 0.7927350427350427

# %%
end = time.time()
print(end - start)
# Out:
# 354.7764587402344

# %%
from torchvision.utils import make_grid

# %%
xx, yy = next(iter(image_dataloaders['validation']))

# %%
ptr.eval()
out = ptr(xx.cuda())
preds = out.argmax(1)
predicted_classes = [image_datasets['dev'].classes[c] for c in preds]
actual_classes = [image_datasets['dev'].classes[c] for c in yy]
imshow(make_grid(xx, nrow=4), fig_size=(8,8))
print(predicted_classes)
print(actual_classes)
# Out:
# ['street', 'street', 'glacier', 'glacier', 'street', 'buildings', 'forest', 'glacier', 'sea', 'sea', 'buildings', 'forest', 'glacier', 'forest', 'forest', 'glacier']
# ['buildings', 'street', 'glacier', 'glacier', 'street', 'buildings', 'forest', 'mountain', 'sea', 'sea', 'buildings', 'forest', 'glacier', 'forest', 'forest', 'glacier']

# %%
all_preds = []
correct_preds = []
with torch.no_grad():
    ptr.eval()
    for xx, yy in image_dataloaders['test']:
        xx = xx.to(device)
        output = ptr(xx)
        all_preds.extend(output.argmax(1).tolist())
        correct_preds.extend(yy.tolist())

# %%
from sklearn import metrics

# %%
all_preds = np.asarray(all_preds)
correct_preds = np.asarray(correct_preds)

# %%
target_names = image_datasets['test'].classes
print(metrics.classification_report(correct_preds, all_preds,target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.78      0.72      0.75       437
#       forest       0.92      0.90      0.91       474
#      glacier       0.69      0.85      0.76       553
#     mountain       0.79      0.74      0.77       525
#          sea       0.84      0.77      0.80       510
#       street       0.84      0.82      0.83       501
#
#    micro avg       0.80      0.80      0.80      3000
#    macro avg       0.81      0.80      0.80      3000
# weighted avg       0.81      0.80      0.80      3000

# %%
confusion_matrix = metrics.confusion_matrix(correct_preds, all_preds)
pd.DataFrame(confusion_matrix, index=target_names, columns=target_names)
# Out:
#            buildings  forest  glacier  mountain  sea  street
# buildings        314      14       27        19   13      50
# forest            14     425        5         8    2      20
# glacier            8       2      469        43   28       3
# mountain           5       2      101       390   27       0
# sea               12       2       67        31  394       4
# street            49      19       10         3    7     413
